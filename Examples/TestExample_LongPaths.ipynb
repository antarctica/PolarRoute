# %% [markdown]
#  Please run the JSON creators found in PreProcessing folder or download an example by runnnig the commeted code below

# %%
import pandas as pd
from RoutePlanner.CellGrid import CellGrid
from RoutePlanner.IO import LoadIcePoints, LoadCurrentPoints
from RoutePlanner.Optimisation import TravelTime

# %%
OptInfo = {}
OptInfo['Bounds Longitude']     = [230,360]
OptInfo['Bounds Latitude']      = [-80,-40]
OptInfo['Grid Spacing (dx,dy)'] = [5,2.5]
OptInfo['Start Time']           = '2017-05-01'
OptInfo['End Time']             = '2017-06-01'
OptInfo['WayPoints']            = pd.read_csv('../resources/WayPoint_LongPaths.csv') 
OptInfo['MaxIceExtent']         = 0.8
OptInfo['Zero Currents']        = True
OptInfo['VariableSpeed']        = False
OptInfo['Time Unit']            = 'days'
OptInfo['VehicleInfo']          = {}
OptInfo['VehicleInfo']['Speed'] = 26.3
OptInfo['VehicleInfo']['Unit']  = 'km/hr'
OptInfo['Start Waypoints']      = None

# %%
icePoints     = LoadIcePoints('../Data/bsose_i122_2013to2017_1day_SeaIceArea.nc',OptInfo['Start Time'],OptInfo['End Time'])
currentPoints = LoadCurrentPoints('../Data/SOSE_surface_velocity_6yearMean_2005-2010.nc')

cellGrid = CellGrid(OptInfo)
cellGrid.addIcePoints(icePoints)
cellGrid.addCurrentPoints(currentPoints)
cellGrid.recursiveSplit(3)

TT = TravelTime(cellGrid)
TT.Dijkstra(verbrose=True)
# Out:
# === Processing Waypoint = LongPathStart ===
# === Processing Waypoint = LongPathEnd ===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jsmith/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/Examples/TestExample_LongPaths.ipynb Cell 4' in <module>
#       <a href='vscode-notebook-cell:/Users/jsmith/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/Examples/TestExample_LongPaths.ipynb#ch0000003?line=6'>7</a> cellGrid.recursiveSplit(3)
#       <a href='vscode-notebook-cell:/Users/jsmith/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/Examples/TestExample_LongPaths.ipynb#ch0000003?line=8'>9</a> TT = TravelTime(cellGrid)
# ---> <a href='vscode-notebook-cell:/Users/jsmith/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/Examples/TestExample_LongPaths.ipynb#ch0000003?line=9'>10</a> TT.Dijkstra(verbrose=True)
#
# File ~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py:198, in TravelTime.Dijkstra(self, verbrose, multiprocessing)
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=195'>196</a>         if verbrose:
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=196'>197</a>             print('=== Processing Waypoint = {} ==='.format(wpt))
# --> <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=197'>198</a>         self._dijkstra(wpt)
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=199'>200</a> # Chaning Dijkstra Information to Paths
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=200'>201</a> self.Dijkstra2Path()
#
# File ~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py:158, in TravelTime._dijkstra(self, wpt_name)
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=154'>155</a> idx        = non_locked['CellIndex'].loc[non_locked['TotalCost'].idxmin()]
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=156'>157</a> # Finding the cost of the nearest neighbours
# --> <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=157'>158</a> Neighbour_index,TT,CrossPoints,CellPoints = self.NeighbourCost(idx)
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=158'>159</a> Neighbour_cost  = np.sum(TT,axis=1) + self.DijkstraInfo[wpt_name]['Info']['TotalCost'][self.DijkstraInfo[wpt_name]['Info']['CellIndex']==idx].iloc[0]
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=160'>161</a> # Determining if the visited time is visited
#
# File ~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py:123, in TravelTime.NeighbourCost(self, index)
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=110'>111</a> '''
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=111'>112</a> Function for computing the shortest travel-time from a cell to its neighbours by applying the Newtonian method for optimisation
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=112'>113</a>
#    (...)
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=119'>120</a>     - If corner of cell is land in adjacent cell then also return 'inf'
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=120'>121</a> '''
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=121'>122</a> # Determining the nearest neighbour index for the cell
# --> <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=122'>123</a> neighbours,neighbours_idx = self.Mesh.getNeightbours(self.Mesh.cellBoxes[index])
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=124'>125</a> # Creating Blank travel-time and crossing point array
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=125'>126</a> TravelTime  = np.zeros((len(neighbours_idx),2))
#
# File ~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/CellGrid.py:160, in CellGrid.getNeightbours(self, selectedCellBox)
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/CellGrid.py?line=157'>158</a> def getNeightbours(self, selectedCellBox):
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/CellGrid.py?line=158'>159</a>     leftNeightbours,leftNeightbours_indx     = self._getLeftNeightbours(selectedCellBox)
# --> <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/CellGrid.py?line=159'>160</a>     rightNeightbours,rightNeightbours_indx   = self._getRightNeightbours(selectedCellBox)
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/CellGrid.py?line=160'>161</a>     topNeightbours,topNeightbours_indx       = self._getTopNeightbours(selectedCellBox)
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/CellGrid.py?line=161'>162</a>     bottomNeightbours,bottomNeightbours_indx = self._getBottomNeightbours(selectedCellBox)
#
# File ~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/CellGrid.py:134, in CellGrid._getRightNeightbours(self, selectedCellBox)
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/CellGrid.py?line=131'>132</a> rightNeightbours_indx = []
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/CellGrid.py?line=132'>133</a> for idx,cellBox in enumerate(self.cellBoxes):
# --> <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/CellGrid.py?line=133'>134</a>     if (cellBox.long == selectedCellBox.long + selectedCellBox.width) and (cellBox.lat <= (selectedCellBox.lat + selectedCellBox.height)) and ((cellBox.lat + cellBox.height) >= selectedCellBox.lat):
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/CellGrid.py?line=134'>135</a>         rightNeightbours_indx.append(idx)
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/CellGrid.py?line=135'>136</a>         rightNeightbours.append(cellBox)
#
# KeyboardInterrupt:

# %%
ax = TT.PlotPaths()
ax.set_xlim([230,305])
ax.set_ylim([-65,-55])
# Out:
# (-65.0, -55.0)

# %%
ax = TT.PlotPaths()

# Plotting the ground truths
GT = pd.read_csv('../resources/GroundTruth_LongPath_Start2End.csv')
GT['Long'] = GT['Long']+360
ax.plot(GT['Long'],GT['Lat'],'r')
GT = pd.read_csv('../resources/GroundTruth_LongPath_End2Start.csv')
GT['Long'] = GT['Long']+360
ax.plot(GT['Long'],GT['Lat'],'r')

ax.set_xlim([230,305])
ax.set_ylim([-65,-55])
# Out:
# (-65.0, -55.0)
