# %%
import pandas as pd
from RoutePlanner.CellGrid import CellGrid
from RoutePlanner.IO import LoadIcePoints, LoadCurrentPoints
from RoutePlanner.Optimisation import TravelTime

# %%
OptInfo = {}
OptInfo['Bounds Longitude']     = [230,360]
OptInfo['Bounds Latitude']      = [-80,-40]
OptInfo['Grid Spacing (dx,dy)'] = [5,2.5]
OptInfo['Start Time']           = '2017-05-01'
OptInfo['End Time']             = '2017-06-01'
OptInfo['WayPoints']            = pd.read_csv('../../resources/WayPoints_TestExample.csv') 
OptInfo['MaxIceExtent']         = 0.8
OptInfo['Zero Currents']        = True
OptInfo['VariableSpeed']        = False
OptInfo['Time Unit']            = 'days'
OptInfo['VehicleInfo']          = {}
OptInfo['VehicleInfo']['Speed'] = 26.3
OptInfo['VehicleInfo']['Unit']  = 'km/hr'
OptInfo['Start Waypoints']      = None

# %%
icePoints     = LoadIcePoints('../../Data/bsose_i122_2013to2017_1day_SeaIceArea.nc',OptInfo['Start Time'],OptInfo['End Time'])
currentPoints = LoadCurrentPoints('../../Data/SOSE_surface_velocity_6yearMean_2005-2010.nc')

cellGrid = CellGrid(OptInfo)
cellGrid.addIcePoints(icePoints)
cellGrid.addCurrentPoints(currentPoints)
cellGrid.recursiveSplit(2)
cellGrid.plot()

# %%
TT = TravelTime(cellGrid)
TT.Dijkstra(verbrose=True)
# Out:
# === Processing Waypoint = ArgentineSea ===
# === Processing Waypoint = MargueriteBay ===

# %%
ax = TT.PlotPaths(routepoints=True)

# %%
TT.PathSmoothing(maxiter=250)
# Out:
# ==================================================
#  PATH: ArgentineSea -> MargueriteBay
# No-Case: df_X=0.625,df_Y=-1.5625; BoxW=0.625; BoxHeight=0.3125; Sp=[301.875,-51.875];Cp=[302.0,-52.5];Np=[302.5,-55.0]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /Users/jsmith/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/Examples/TestExample_PathOptimisation/PathSmoothing_ArgentineSea_MargueriteBay.ipynb Cell 6' in <module>
# ----> <a href='vscode-notebook-cell:/Users/jsmith/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/Examples/TestExample_PathOptimisation/PathSmoothing_ArgentineSea_MargueriteBay.ipynb#ch0000005?line=0'>1</a> TT.PathSmoothing(maxiter=250)
#
# File ~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py:268, in TravelTime.PathSmoothing(self, maxiter)
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=265'>266</a> Np  = tuple(Points[id+2,:])
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=266'>267</a> nc = NewtonianCurve(self.Mesh,Sp,Cp,Np,self.OptInfo['VehicleInfo']['Speed'])
# --> <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=267'>268</a> TravelTime, CrossingPoint = nc.value()
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=269'>270</a> if (np.isnan(CrossingPoint)).any():
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Optimisation.py?line=270'>271</a>     CrossingPoint = np.array([[Cp[0],Cp[1]]])
#
# File ~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Function.py:760, in NewtonianCurve.value(self)
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Function.py?line=757'>758</a> else:
#     <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Function.py?line=758'>759</a>     print('No-Case: df_X={},df_Y={}; BoxW={}; BoxHeight={}; Sp=[{},{}];Cp=[{},{}];Np=[{},{}]'.format(self.df_x,self.df_y,self.Box1.width/2,self.Box1.height/2,self.Sp[0],self.Sp[1],self.Cp[0],self.Cp[1],self.Np[0],self.Np[1]))
# --> <a href='file:///~/Documents/Research/Researcher_BAS/RoutePlanning/SDADT-pyRoutePlanner/RoutePlanner/Function.py?line=759'>760</a> return TravelTime, CrossPoint
#
# UnboundLocalError: local variable 'TravelTime' referenced before assignment

# %%
ax = TT.PlotPaths()
